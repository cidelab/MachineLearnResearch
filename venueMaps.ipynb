# %%
import pandas as pd
data = pd.read_csv("Arenas.csv")
data
# Out:
#                                              Name  Capacity       League  \
# 0                                   Boston Garden   19580.0          NaN
# 1                           The Rose Garden Arena   19980.0          NaN
# 2                                  Vaillant Arena    7080.0          NaN
# 3                           Madison Square Garden   20789.0          NaN
# 4                                    Carrier Dome   49250.0          NaN
# 5                               Hinkle Fieldhouse    9100.0          NaN
# 6                                 Barclays Center   18103.0          NaN
# 7                                    The Palestra    8722.0          NaN
# 8                                  Movistar Arena   12000.0          NaN
# 9                                    Rogers Place   19500.0          NaN
# 10                         McKale Memorial Center   14545.0          NaN
# 11                                Golden 1 Center   17608.0          NaN
# 12                               Palau Sant Jordi   17000.0          NaN
# 13                                    Perth Arena   15000.0          NaN
# 14                           Little Caesars Arena   20491.0          NaN
# 15                                   Tauron Arena   15328.0          NaN
# 16                         AmericanAirlines Arena       NaN          NaN
# 17                               Nationwide Arena       NaN          NaN
# 18                                  United Center       NaN          NaN
# 19                                        The Pit       NaN          NaN
# 20              Dongguan Sports Center Basketball       NaN          NaN
# 21                                   Bilbao Arena       NaN          NaN
# 22                                    Tele2 Arena       NaN          NaN
# 23                       Ankara Arena Sports Hall       NaN          NaN
# 24                                         The O2       NaN          NaN
# 25                          STAPLES Center Lakers   21000.0          NBA
# 26                        Bankers Life Fieldhouse       NaN          NaN
# 27                     Mercedes-Benz Arena Berlin   17000.0          NaN
# 28                                    Perth Arena       NaN          NaN
# 29                      Barclaycard Arena Hamburg   16000.0          NaN
# 30                                      Palais 12   18000.0          NaN
# 31                          Hovet Arena Stockholm    9000.0          NaN
# 32                   Mercedes-Benz Arena Shanghai   18000.0          NaN
# 33                                 Ahoy Rotterdam   15818.0          NaN
# 34                                  The SSE Hydro   13000.0          NaN
# 35                         The SSE Arena, Wembley   12740.0          NaN
# 36                             �lker Sports Arena   15000.0   Euroleague
# 37                Nikos Galis Olympic Indoor Hall   18500.0   Euroleague
# 38                         Megasport Sport Palace   14000.0   Euroleague
# 39                   Peace and Friendship Stadium   14940.0   Euroleague
# 40                         Menora Mivtachim Arena   11060.0   Euroleague
# 41                      Abdi ?pek�i Sport Complex   12500.0   Euroleague
# 42                                  Kombank Arena   18386.0   Euroleague
# 43                  Palacio de Deportes de Madrid   15000.0   Euroleague
# 44                  Pabell�n Fernando Buesa Arena   15504.0   Euroleague
# 45                                 �algiris arena   15552.0   Euroleague
# 46                                Palau Blaugrana   12000.0  Eurloleague
# 47                                    Brose Arena    6249.0   Euroleague
# 48                               Mediolanum Forum   12700.0   Euroleague
# 49  Palacio de Deportes Jos� Mar�a Mart�n Carpena   11300.0   Euroleague
#
#      longitude   latitude
# 0   -71.062100  42.366198
# 1  -122.666842  45.531565
# 2     9.826352  46.798543
# 3   -73.993439  40.750504
# 4   -76.136316  43.036227
# 5   -86.167220  39.843613
# 6   -73.975035  40.682495
# 7   -75.188703  39.951391
# 8   -70.661931 -33.462675
# 9  -113.497819  53.546996
# 10 -110.946075  32.230302
# 11 -121.499619  38.580641
# 12    2.152632  41.363417
# 13  115.852110 -31.948434
# 14  -83.055236  42.341140
# 15   19.990721  50.067656
# 16  -80.186969  25.781401
# 17  -83.006059  39.969213
# 18  -87.674176  41.880691
# 19 -106.632262  35.067034
# 20  113.751732  23.024018
# 21   -2.926074  43.252224
# 22   18.083964  59.291278
# 23   32.844011  39.937827
# 24    0.003154  51.503038
# 25 -118.267360  34.043006
# 26  -86.155464  39.763930
# 27   13.443632  52.506314
# 28  115.852110 -31.948434
# 29    9.899232  53.589310
# 30    4.342191  50.901045
# 31   18.081872  59.294914
# 32  121.493103  31.189252
# 33    4.488184  51.882791
# 34   -4.285274  55.860176
# 35   -0.282586  51.558096
# 36   29.104715  40.992820
# 37   23.783942  38.038170
# 38   37.539649  55.786475
# 39   23.667726  37.942391
# 40   34.791319  32.061087
# 41   28.919412  40.996839
# 42   20.421289  44.814146
# 43   -3.671755  40.423818
# 44   -2.641572  42.864166
# 45   23.914565  54.890459
# 46    2.118153  41.380013
# 47   10.920360  49.879012
# 48    9.142295  45.401412
# 49   -4.460516  36.682633

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))

map = Basemap(resolution='l',projection='merc', llcrnrlat=32,urcrnrlat=64,llcrnrlon=-20,urcrnrlon=40,lat_ts=(-20+40)/2)
#map = Basemap()
map.drawcoastlines(linewidth=0.5)
map.drawcountries(linewidth=0.5)

plt.show()

# %%
map = Basemap(projection='aeqd', lat_0=0,lon_0=0)
map.drawmapboundary(fill_color='aqua')
map.fillcontinents(color='coral', lake_color='aqua')
map.drawcoastlines()
plt.show()
# Out:
# C:\Users\Carlos\Anaconda2\envs\mapping\lib\site-packages\mpl_toolkits\basemap\__init__.py:1767: MatplotlibDeprecationWarning: The get_axis_bgcolor function was deprecated in version 2.0. Use get_facecolor instead.
#   axisbgc = ax.get_axis_bgcolor()
