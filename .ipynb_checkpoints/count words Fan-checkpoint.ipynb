# %%
import re;

# %%
a = "To be unique impressive in design Would like it to be iconic Not like the shed at Kirkby Closer to Kings dock Lets make it a fantasty stadium where alternative events like the NHL would love to play Do NOT want a standard bowl i like it to be accessible by train and car Would like higher steeped sides stands to create an intimidating environment Would love them to really go for the fans zone create a leisure city around the outside of the stadium Include museum, places to eat, activities for kids. Go for the whole works So for fans coming up to the stadium they could spend a good amount of time in the area and really become engrossed in what it means to be an Everton supporter"
a = a.replace(',', '')
a = re.sub(r'\b\w{1,3}\b', '', a)

# %%
arrs = a.split()
arrs.sort()
arrs
# Out:
# ['Closer',
#  'Everton',
#  'Include',
#  'Kings',
#  'Kirkby',
#  'Lets',
#  'Would',
#  'Would',
#  'Would',
#  'accessible',
#  'activities',
#  'alternative',
#  'amount',
#  'area',
#  'around',
#  'become',
#  'bowl',
#  'city',
#  'coming',
#  'could',
#  'create',
#  'create',
#  'design',
#  'dock',
#  'engrossed',
#  'environment',
#  'events',
#  'fans',
#  'fans',
#  'fantasty',
#  'good',
#  'higher',
#  'iconic',
#  'impressive',
#  'intimidating',
#  'kids.',
#  'leisure',
#  'like',
#  'like',
#  'like',
#  'like',
#  'like',
#  'love',
#  'love',
#  'make',
#  'means',
#  'museum',
#  'outside',
#  'places',
#  'play',
#  'really',
#  'really',
#  'shed',
#  'sides',
#  'spend',
#  'stadium',
#  'stadium',
#  'stadium',
#  'standard',
#  'stands',
#  'steeped',
#  'supporter',
#  'them',
#  'they',
#  'time',
#  'train',
#  'unique',
#  'want',
#  'what',
#  'where',
#  'whole',
#  'works',
#  'would',
#  'zone']

# %%
from operator import itemgetter

counts = dict()

for w in arrs:
        if w not in counts:
            counts[w] = 1
        else:
            counts[w] += 1
            
#sort by value...
lst = list()
for key, value in counts.items():
    lst.append((key, value))
    
lst.sort(key = itemgetter(0,1), reverse = True)

lst
# Out:
# [('zone', 1),
#  ('would', 1),
#  ('works', 1),
#  ('whole', 1),
#  ('where', 1),
#  ('what', 1),
#  ('want', 1),
#  ('unique', 1),
#  ('train', 1),
#  ('time', 1),
#  ('they', 1),
#  ('them', 1),
#  ('supporter', 1),
#  ('steeped', 1),
#  ('stands', 1),
#  ('standard', 1),
#  ('stadium', 3),
#  ('spend', 1),
#  ('sides', 1),
#  ('shed', 1),
#  ('really', 2),
#  ('play', 1),
#  ('places', 1),
#  ('outside', 1),
#  ('museum', 1),
#  ('means', 1),
#  ('make', 1),
#  ('love', 2),
#  ('like', 5),
#  ('leisure', 1),
#  ('kids.', 1),
#  ('intimidating', 1),
#  ('impressive', 1),
#  ('iconic', 1),
#  ('higher', 1),
#  ('good', 1),
#  ('fantasty', 1),
#  ('fans', 2),
#  ('events', 1),
#  ('environment', 1),
#  ('engrossed', 1),
#  ('dock', 1),
#  ('design', 1),
#  ('create', 2),
#  ('could', 1),
#  ('coming', 1),
#  ('city', 1),
#  ('bowl', 1),
#  ('become', 1),
#  ('around', 1),
#  ('area', 1),
#  ('amount', 1),
#  ('alternative', 1),
#  ('activities', 1),
#  ('accessible', 1),
#  ('Would', 3),
#  ('Lets', 1),
#  ('Kirkby', 1),
#  ('Kings', 1),
#  ('Include', 1),
#  ('Everton', 1),
#  ('Closer', 1)]

# %%
top_n = list()

for key, val in counts.items():
    top_n.append((val, key))

top_n.sort()

top_n
# Out:
# [(1, 'Closer'),
#  (1, 'Everton'),
#  (1, 'Include'),
#  (1, 'Kings'),
#  (1, 'Kirkby'),
#  (1, 'Lets'),
#  (1, 'accessible'),
#  (1, 'activities'),
#  (1, 'alternative'),
#  (1, 'amount'),
#  (1, 'area'),
#  (1, 'around'),
#  (1, 'become'),
#  (1, 'bowl'),
#  (1, 'city'),
#  (1, 'coming'),
#  (1, 'could'),
#  (1, 'design'),
#  (1, 'dock'),
#  (1, 'engrossed'),
#  (1, 'environment'),
#  (1, 'events'),
#  (1, 'fantasty'),
#  (1, 'good'),
#  (1, 'higher'),
#  (1, 'iconic'),
#  (1, 'impressive'),
#  (1, 'intimidating'),
#  (1, 'kids.'),
#  (1, 'leisure'),
#  (1, 'make'),
#  (1, 'means'),
#  (1, 'museum'),
#  (1, 'outside'),
#  (1, 'places'),
#  (1, 'play'),
#  (1, 'shed'),
#  (1, 'sides'),
#  (1, 'spend'),
#  (1, 'standard'),
#  (1, 'stands'),
#  (1, 'steeped'),
#  (1, 'supporter'),
#  (1, 'them'),
#  (1, 'they'),
#  (1, 'time'),
#  (1, 'train'),
#  (1, 'unique'),
#  (1, 'want'),
#  (1, 'what'),
#  (1, 'where'),
#  (1, 'whole'),
#  (1, 'works'),
#  (1, 'would'),
#  (1, 'zone'),
#  (2, 'create'),
#  (2, 'fans'),
#  (2, 'love'),
#  (2, 'really'),
#  (3, 'Would'),
#  (3, 'stadium'),
#  (5, 'like')]

# %%
s = "london bridge is falling down falling down falling down london bridge is falling down my fair lady"

# %%
    """Return the n most frequently occuring words in s."""
    
    # TODO: Count the number of occurences of each word in s
    arrs = a.split()
    arrs.sort(reverse=True)
    
    # TODO: Sort the occurences in descending order (alphabetically in case of ties)
    counts = dict()
    
    for w in arrs:
        if w not in counts:
            counts[w] = 1
        else:
            counts[w] += 1
    
    lst = list()
    for key, wrd in counts.items():
        lst.append( (wrd, key) )
    
    top_n = list()
    for key, wrd in lst[:n]:
        top_n.append((wrd, key))
        
    #top_n.sort(key=itemgetter(1))
    
    # TODO: Return the top n words as a list of tuples (<word>, <count>)
    #return top_n
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-95b77c742928> in <module>()
#      19
#      20 top_n = list()
# ---> 21 for key, wrd in lst[:n]:
#      22     top_n.append((wrd, key))
#      23
#
# NameError: name 'n' is not defined

# %%
#final code...
# TODO: Count the number of occurences of each word in s
#"cat bat mat cat bat cat", 3
#"betty bought a bit of butter but the butter was bitter", 3
#"london bridge is falling down falling down falling down london bridge is falling down my fair lady", 5)

import operator

s = a #"london bridge is falling down falling down falling down london bridge is falling down my fair lady"
n = 5
    
arrs = s.split()
counts = dict()
    
for w in arrs:
    if w not in counts:
        counts[w] = 1
    else:
        counts[w] += 1

# TODO: Sort the occurences in descending order (alphabetically in case of ties)
top_n = counts.items()

top_n.sort(key=lambda row: row[0])
top_n.sort(key=lambda row: row[1], reverse = True)
    
t = list()
for key, val in top_n[:n]:
    t.append((key, val))

t
# Out:
# [('to', 9), ('the', 8), ('a', 4), ('be', 4), ('for', 4)]

# %% [markdown]
# Implement a function count_words() in Python that takes as input a string s and a number n, and returns the n most frequently-occuring words in s. The return value should be a list of tuples - the top n words paired with their respective counts [(<word>, <count>), (<word>, <count>), ...], sorted in descending count order.
#
# You can assume that all input will be in lowercase and that there will be no punctuations or other characters (only letters and single separating spaces). In case of a tie (equal count), order the tied words alphabetically.
#
# E.g.:
#
# print count_words("betty bought a bit of butter but the butter was bitter",3)
# Output:
#
# [('butter', 2), ('a', 1), ('betty', 1)]
# Instructions
# This is a Python programming exercise. A simple code editor will open up in the next node. Follow the instructions in the template code provided to complete the exercise (look for "TODO"s).
#
# You can execute your program using the Test Run button. Output is shown below the editor area.
#
# To verify your solution, use the Submit button, and watch for feedback on the right hand side. Feel free to iterate as many times as you need.
#
# Your code did not pass one or more tests.
#
# Please look at the output below the editor, fix the issues and try to submit again.
# Evaluating...
# [FAILED] Wrong word found: 'bat' where it should be 'cat'
# Inputs: ('cat bat mat cat bat cat', 3)
# Output: [('cat', 3), ('bat', 1), ('cat', 3)]
#
#
# [FAILED] Wrong word found: 'bitter' where it should be 'betty'
# Inputs: ('betty bought a bit of butter but the butter was bitter', 3)
# Output: [('butter', 2), ('a', 1), ('betty', 1)]
#
#
# [FAILED] Wrong word found: 'a' where it should be 'dddd'
# Inputs: ('a bb bb ccc ccc ccc dddd dddd dddd dddd', 2)
# Output: [('a', 1), ('dddd', 4)]
#
#
# [FAILED] Wrong word found: 'bridge' where it should be 'down'
# Inputs: ('london bridge is falling down falling down falling down london bridge is falling down my fair lady', 5)
# Output: [('bridge', 2), ('fair', 1), ('my', 1), ('is', 2), ('down', 4)]

# %%
everton
